# %% [markdown]
# <a href="https://colab.research.google.com/github/MulatYazew/Supervised_Learning_Labs/blob/main/denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install scipy
# !pip install numpy
# !pip install scikit-learn
# !pip install tensorflow

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/MyDrive/my_data/')

# %%
df1 = np.load('data/signal_waves_noisy.npy')
df2 = np.load('data/signal_waves.npy')

# %%
print(df2[:5])

# %%
print("Shape of df1 (noisy signals):", df1.shape)
# Out:
# Shape of df1 (noisy signals): (200000, 2, 600)

# %% [markdown]
# Check missing values

# %%
missing_df1 = np.isnan(df1).sum()
print(missing_df1)

zero_count_df1 = np.sum(df1 == 0)

print(zero_count_df1)
# Out:
# 0
# 200000
